# %%
#Q-1.Find Simple Interest.
p = float(input("Enter principal: "))
r = float(input("Enter Rate of Interest: "))
t = float(input("Enter Time(years): "))
si = (p * r * t)/100
print(f"Simple Interest: {si}")
# Out:
# Enter principal:  1250000
# Enter Rate of Interest:  1
# Enter Time(years):  5
# Simple Interest: 62500.0

# %%
# Q.2 Find maximum of 2 numbers.
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print(f"The maximum is: {max(num1, num2)}")
# Out:
# Enter first number:  5
# Enter second number:  3
# The maximum is: 5.0

# %%
# Q.3 Print 1 to 5.
for i in range(1,6):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Q.4 Find length of string.
text = input("Enter a string")
print(f"The length of the string is: {len(text)}")
# Out:
# Enter a string 5
# The length of the string is: 1

# %%
# Q.5 Print a welcome message.
name = input("Enter your name: ")
print(f"Welcome to Python programming, {name}!")
# Out:
# Enter your name:  Jaydeep
# Welcome to Python programming, Jaydeep!

# %%
# Q.6 Print first character of a string.
text = input("Enter a string: ")
if text:
    print(f"First character: {text[0]}")
# Out:
# Enter a string:  12
# First character: 1

# %%
# Q.7 Print last character of a string.
text = input("Enter a string: ")
if text:
    print(f"First character: {text[-1]}")
# Out:
# Enter a string:  3
# First character: 3

# %%
# Q.8 Cheak positive or negative.
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("The number is zero")
# Out:
# Enter a number:  111
# Positive

# %%
# Q.9 Add three numbers.
a = float(input("Num 1: "))
b = float(input("Num 2: "))
c = float(input("Num 3: "))
print(f"Total sum: {a + b + c}")
# Out:
# Num 1:  7
# Num 2:  9
# Num 3:  11
# Total sum: 27.0

# %%
# Q.10 Take an input from user & make a task.
# A simple string trick: Reverse whatever the user types
user_input = input("Enter a word to see a trick: ")
print(f"Abracadabra gili gili chhuu!!! Your word backwords is: {user_input[::-1]}")
# Out:
# Enter a word to see a trick:  2
# Abracadabra gili gili chhuu!!! Your word backwords is: 2
