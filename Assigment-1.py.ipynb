# %%
#Q-1.Welcome Message.
print("Welcome to python programming")
# Out:
# Welcome to python programming

# %%
#Q-2.Whiscape Characters.
print("\nRajesh Kumar \nFlat no.101, Sunshine Apartments\nMG Road, Sector 15\nRajkot,\nPincode: 360004\nIndia.")
# Out:
# Rajesh Kumar
# Flat no.101, Sunshine Apartments
# MG Road, Sector 15
# Rajkot,
# Pincode: 360004
# India.

# %%
#Q-3.Basic Mathematical Operations.
x=150
y=120.50
print("Addition:",x+y)
print("Substraction:",x-y)
print("Multiplication:",x*y)
print("Division:",x/y)
# Out:
# Addition: 270.5
# Substraction: 29.5
# Multiplication: 18075.0
# Division: 1.2448132780082988

# %%
#Q-4.Area of Circle.
radius = float(input("Enter the radius: "))
area = 3.14*(radius ** 2)
circumference = 2 * 3.14 * radius
print(f"Area: {area}")
print(f"Circcumference: {circumference}")
# Out:
# Enter the radius:  4
# Area: 50.24
# Circcumference: 25.12

# %%
#Q-5.Simple Intrest.
P = float(input("Enter Principal amount: "))
R = float(input("Enter Rate of Intrest: "))
T = float(input("Enter Time (in yeras): "))
simple_intrest = (P * R * T) / 100
print(f"The Simple Intrest is: {simple_intrest}")
# Out:
# Enter Principal amount:  30000
# Enter Rate of Intrest:  5
# Enter Time (in yeras):  2008
# The Simple Intrest is: 3012000.0

# %%
#Q-6.Area and Perimeter of Rectangle.
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
perimeter = 2 * (length + width)
print(f"Area: {area}, Perimeter:{perimeter}")
# Out:
# Enter length:  5
# Enter width:  4
# Area: 20.0, Perimeter:18.0

# %%
#Q-7.Area and perimeter of square.
side = float(input("Enter the side of the square: "))
area = side * side
perimeter = 4 * side
print(f"Area : {area}")
print(f"perimeter: {perimeter}")
# Out:
# Enter the side of the square:  6
# Area : 36.0
# perimeter: 24.0

# %%
#Q-8.Perimeter of triangle.
side_a = float(input("Enter the length of side a: "))
side_b = float(input("Enter the length of side b: "))
side_c = float(input("Enter the length of side c: "))
perimeter = side_a + side_b + side_c
print("The perimeter of the triangle is: ",perimeter)
# Out:
# Enter the length of side a:  7
# Enter the length of side b:  9
# Enter the length of side c:  8
# The perimeter of the triangle is:  24.0

# %%
#Q-9.Calculate Area and Perimeter of a square.
side = float(input("Enter the side of the  square: "))
area = side * side 
perimeter = 4 * side
# Out:
# Enter the side of the  square:  9

# %%
#Q-10.Calculates perimeter a using Square.
side = float(input("Enter the side of the square: "))
perimeter = 4 * side
# Out:
# Enter the side of the square:  10
